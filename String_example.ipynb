# %%
a = "spam"

# %%
a
# Out:
# 'spam'

# %%
a[1]
# Out:
# 'p'

# %%
a[1:2]
# Out:
# 'p'

# %%
a[1:3]
# Out:
# 'pa'

# %%
a += "-test"

# %%
a
# Out:
# 'spam-test'

# %%
a.split('-')
# Out:
# ['spam', 'test']

# %%
a.replace('test','abc')
# Out:
# 'spam-abc'

# %%
a
# Out:
# 'spam-test'
