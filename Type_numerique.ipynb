# %%
4 - 1
# Out:
# 3

# %%
4.0 - 1.0
# Out:
# 3.0

# %%
4.0 - 0.1
# Out:
# 3.9

# %%
int(3.1415)
# Out:
# 3

# %%
float(3)
# Out:
# 3.0

# %%
num = 1 / 3.0

# %%
num
# Out:
# 0.3333333333333333

# %%
print(num)
# Out:
# 0.3333333333333333

# %%
'%e' % num
# Out:
# '3.333333e-01'

# %%
'%4.2f' % num
# Out:
# '0.33'

# %%
'{0:4.2f}'.format(num)
# Out:
# '0.33'

# %%
1.1 + 2.2 == 3.3
# Out:
# False

# %%
int(1.1 + 2.2) == int(3.3)
# Out:
# True

# %%
from __future__ import division
10 / 4
# Out:
# 2.5

# %%
10 // 4
# Out:
# 2
