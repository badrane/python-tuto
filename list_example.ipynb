# %%
a = [1,3,4,5]

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 4

# %%
a[3]= 67

# %%
a
# Out:
# [1, 3, 4, 67]

# %%
a.append(123)

# %%
a
# Out:
# [1, 3, 4, 67, 123]

# %%
a += [1,3]

# %%
a
# Out:
# [1, 3, 4, 67, 123, 1, 3]

# %%
len(a)
# Out:
# 7

# %%
a.insert(2,99)

# %%
a
# Out:
# [1, 3, 99, 4, 67, 123, 1, 3, 2]

# %%
a.sort()

# %%
a
# Out:
# [1, 1, 2, 3, 3, 4, 67, 99, 123]

# %%
a.reverse()

# %%
a
# Out:
# [123, 99, 67, 4, 3, 3, 2, 1, 1]

# %%
a.index(123)
# Out:
# 0

# %%
a.index(67)
# Out:
# 2

# %%
a.pop()
# Out:
# 1

# %%
a
# Out:
# [123, 99, 67, 4, 3, 3, 2, 1]
